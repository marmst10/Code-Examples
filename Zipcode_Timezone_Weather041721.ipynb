# %%
#install pyzipcode
pip install pyzipcode
# Out:
# ...
#   Created wheel for pyzipcode: filename=pyzipcode-3.0.1-py3-none-any.whl size=1932419 sha256=2dde5f21ad621fbcbc6cd1839a9fbe3ea369bd49cba973d2a5a8ebf471e2279e
#   Stored in directory: c:\users\conno\appdata\local\pip\cache\wheels\f6\01\8e\7424c7e867eb5db7bb9531b09b4d968f23e5ac45ec5e7c3cb3
# Successfully built pyzipcode
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries
from pyzipcode import ZipCodeDatabase
import pandas as pd
import numpy as np

# %%
#assign zipcode database
zcdb = ZipCodeDatabase()

#export csv
#zcdb.to_csv('ZipCodeDatabase.csv')

# %%
type(zcdb)
# Out:
# pyzipcode.ZipCodeDatabase

# %%
#couldn't get this to work
#import zipcodes for missing games
weather = pd.read_csv('C:/Users/conno/OneDrive/Desktop/STAT 8940 - Applied Analysis Project/Data/missing_weather_type3.csv')

#list of zipcode attributes
weather_zip = []
for i in range(len(weather)-1):
    weather_zip.append(zcdb[weather["zip"][i]])
weather_zip

# %%
zcdb[weather["zip"][1]]
# Out:
# ZipCode(zip='32202', city='Jacksonville', state='FL', longitude=-81.65101, latitude=30.328539, timezone=-5, dst=1)

# %%
weather["zip"][1]
# Out:
# '32202'

# %%
#I think the weather dataframe is mucking up the weather search below.
#del weather
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-2655011256ee> in <module>
#       1 #I think the weather dataframe is mucking up the weather search below.
#       2 #del weather
# ----> 3 weather
#
# NameError: name 'weather' is not defined

# %%
#used to retrieve and parse historical weather data from World Weather
#Online into pandas DataFrame and CSV file
#pip install wwo-hist
from wwo_hist import retrieve_hist_data
zipcode = ["32202"]
hist_weather_data_1 = retrieve_hist_data("d44e502519aa4821af5205304211704",
                                zipcode,
                                "13-SEP-2015",
                                "13-SEP-2015",
                                6,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for 32202
#
#
# Currently retrieving data for 32202: from 2015-09-13 to 2015-09-13
# Time elapsed (hh:mm:ss.ms) 0:00:00.583741
#
#
# export 32202 completed!

# %%
#can this be inserted into an empty list?
temp = []
temp.append(hist_weather_data_1)
temp[0]
# Out:
# [            date_time maxtempC mintempC totalSnow_cm sunHour uvIndex  \
#  0 2015-09-13 00:00:00       29       21          0.0    11.6       6
#  1 2015-09-13 06:00:00       29       21          0.0    11.6       6
#  2 2015-09-13 12:00:00       29       21          0.0    11.6       6
#  3 2015-09-13 18:00:00       29       21          0.0    11.6       6
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
#  0                 0  07:25 AM  07:51 PM  07:10 AM  ...           10
#  1                 0  07:25 AM  07:51 PM  07:10 AM  ...           14
#  2                 0  07:25 AM  07:51 PM  07:10 AM  ...            5
#  3                 0  07:25 AM  07:51 PM  07:10 AM  ...           11
#
#    cloudcover humidity precipMM pressure tempC visibility winddirDegree  \
#  0        100       98      0.0     1011    23          0           251
#  1         30       93      0.1     1013    21         10           338
# ...

# %%
type(hist_weather_data_1)
# Out:
# list

# %%
weather = pd.read_csv('C:/Users/conno/OneDrive/Desktop/STAT 8940 - Applied Analysis Project/Data/missing_weather_type3.csv')
#check index range
#range(len(weather)-1)
#weather["game_date"][70]
#zipcode = [weather["zip"][1]]
#zipcode
print(weather.columns)
weather["game_date"][5:12]
# Out:
# Index(['game_date', 'weather', 'stadium_id', 'stadium', 'game_stadium',
#        'start_time', 'address', 'zip', 'timezone', 'local_start_time'],
#       dtype='object')
# 5     15-Nov-2015
# 6     15-Nov-2015
# 7     19-Nov-2015
# 8     29-Nov-2015
# 9     29-Nov-2015
# 10    13-Dec-2015
# 11    10-Dec-2015
# Name: game_date, dtype: object

# %%
#create list to input weather data
#hist_weather_data = []

for i in range(len(weather)-1-5):
    zipcode = [weather["zip"][i+5]]#the function wants a list
    temp = retrieve_hist_data("d44e502519aa4821af5205304211704",
                                zipcode,
                                weather["game_date"][i+5],
                                weather["game_date"][i+5],
                                6,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
    hist_weather_data.append(temp)
# Out:
# Retrieving weather data for 54307
#
#
# Currently retrieving data for 54307: from 2015-11-15 to 2015-11-15
# Time elapsed (hh:mm:ss.ms) 0:00:01.574194
#
#
# export 54307 completed!
#
#
#
#
# Retrieving weather data for 80204
#
#
# Currently retrieving data for 80204: from 2015-11-15 to 2015-11-15
# Time elapsed (hh:mm:ss.ms) 0:00:00.487009
#
#
# export 80204 completed!
#
#
#
#
# Retrieving weather data for 32202
#
#
# Currently retrieving data for 32202: from 2015-11-19 to 2015-11-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.513664
#
#
# export 32202 completed!
#
#
#
#
# Retrieving weather data for 07073
#
#
# Currently retrieving data for 07073: from 2015-11-29 to 2015-11-29
# Time elapsed (hh:mm:ss.ms) 0:00:00.459415
#
#
# export 07073 completed!
#
#
#
#
# Retrieving weather data for 32202
#
#
# Currently retrieving data for 32202: from 2015-11-29 to 2015-11-29
# Time elapsed (hh:mm:ss.ms) 0:00:00.503544
#
#
# export 32202 completed!
#
#
#
#
# Retrieving weather data for 32202
#
#
# ...

# %%
#missed the last one somehow
zipcode = [weather["zip"][70]]#the function wants a list
temp = retrieve_hist_data("d44e502519aa4821af5205304211704",
                            zipcode,
                            weather["game_date"][70],
                            weather["game_date"][70],
                            6,
                            location_label = False,
                            export_csv = True,
                            store_df = True)
hist_weather_data.append(temp)
# Out:
# Retrieving weather data for HA9
#
#
# Currently retrieving data for HA9: from 2017-10-01 to 2017-10-01
# Time elapsed (hh:mm:ss.ms) 0:00:00.911623
#
#
# export HA9 completed!

# %%
i
# Out:
# 5

# %%
hist_weather_data[70]
# Out:
# [            date_time maxtempC mintempC totalSnow_cm sunHour uvIndex  \
#  0 2017-10-01 00:00:00       17       15          0.0     5.7       4
#  1 2017-10-01 06:00:00       17       15          0.0     5.7       4
#  2 2017-10-01 12:00:00       17       15          0.0     5.7       4
#  3 2017-10-01 18:00:00       17       15          0.0     5.7       4
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
#  0                72  05:00 PM  01:42 AM  07:02 AM  ...           34
#  1                72  05:00 PM  01:42 AM  07:02 AM  ...           22
#  2                72  05:00 PM  01:42 AM  07:02 AM  ...           25
#  3                72  05:00 PM  01:42 AM  07:02 AM  ...           30
#
#    cloudcover humidity precipMM pressure tempC visibility winddirDegree  \
#  0        100       83      0.7     1013    15          2           182
#  1        100       89      0.5     1012    16          2           184
# ...

# %%
pd_hist_weather_data = hist_weather_data[0][0]
for i in range(len(weather)-2):
    pd_hist_weather_data = pd_hist_weather_data.append(hist_weather_data[i+1][0])
pd_hist_weather_data
# Out:
#              date_time maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# 0  2015-09-13 00:00:00       29       21          0.0    11.6       6
# 1  2015-09-13 06:00:00       29       21          0.0    11.6       6
# 2  2015-09-13 12:00:00       29       21          0.0    11.6       6
# 3  2015-09-13 18:00:00       29       21          0.0    11.6       6
# 0  2015-09-20 00:00:00       33       23          0.0    11.6       6
# ..                 ...      ...      ...          ...     ...     ...
# 3  2015-11-01 18:00:00       19       11          0.0     8.7       5
# 0  2017-09-24 00:00:00       21       14          0.0    11.6       5
# 1  2017-09-24 06:00:00       21       14          0.0    11.6       5
# 2  2017-09-24 12:00:00       21       14          0.0    11.6       5
# 3  2017-09-24 18:00:00       21       14          0.0    11.6       5
#
#    moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# ...

# %%
#missed one. again..
pd_hist_weather_data = pd_hist_weather_data.append(hist_weather_data[70][0])
pd_hist_weather_data
#and... accidentally put 4 extra rows on. just gonna export to excel since
#i'm doing the more complex analysis there
# Out:
#              date_time maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# 0  2015-09-13 00:00:00       29       21          0.0    11.6       6
# 1  2015-09-13 06:00:00       29       21          0.0    11.6       6
# 2  2015-09-13 12:00:00       29       21          0.0    11.6       6
# 3  2015-09-13 18:00:00       29       21          0.0    11.6       6
# 0  2015-09-20 00:00:00       33       23          0.0    11.6       6
# ..                 ...      ...      ...          ...     ...     ...
# 3  2017-10-01 18:00:00       17       15          0.0     5.7       4
# 0  2017-10-01 00:00:00       17       15          0.0     5.7       4
# 1  2017-10-01 06:00:00       17       15          0.0     5.7       4
# 2  2017-10-01 12:00:00       17       15          0.0     5.7       4
# 3  2017-10-01 18:00:00       17       15          0.0     5.7       4
#
#    moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# ...

# %%
#this is all troubleshooting for above^^
'''
temp = hist_weather_data[0][0]
pd_hist_weather_data = temp.append(hist_weather_data[1][0])
pd_hist_weather_data
#pd_hist_weather_data = pd_hist_weather_data.append(hist_weather_data[2][0])
#del pd_hist_weather_data
i = 0
print(4*(i+1)-3)
print(4*(i+1)-2)
print(4*(i+1)-1)
print(4*(i+1))
i = 1
print(4*(i+1)-3)
print(4*(i+1)-2)
print(4*(i+1)-1)
print(4*(i+1))
# Out:
#             date_time maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# 0 2015-09-13 00:00:00       29       21          0.0    11.6       6
# 1 2015-09-13 06:00:00       29       21          0.0    11.6       6
# 2 2015-09-13 12:00:00       29       21          0.0    11.6       6
# 3 2015-09-13 18:00:00       29       21          0.0    11.6       6
# 0 2015-09-20 00:00:00       33       23          0.0    11.6       6
# 1 2015-09-20 06:00:00       33       23          0.0    11.6       6
# 2 2015-09-20 12:00:00       33       23          0.0    11.6       6
# 3 2015-09-20 18:00:00       33       23          0.0    11.6       6
#
#   moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# 0                 0  07:25 AM    07:51 PM  07:10 AM  ...           10
# 1                 0  07:25 AM    07:51 PM  07:10 AM  ...           14
# 2                 0  07:25 AM    07:51 PM  07:10 AM  ...            5
# ...

# %%
pd_hist_weather_data.to_csv('pd_hist_weather_data.csv')
